# %%
import random as rnd
import sys
game_word = ['книга', 'сахалин','месяц','зуб']
def gameplay():
    if len(game_word) == 0:
        print('Игра закончена')
        sys.exit('Игра закончена')
    health = int
    d = {'лёгкий': 7, 'средний': 5, 'сложный': 3}
    
    print('Введите сложность игры')
    choose = str(input())
    health = d[choose]
    
    
    rnd.shuffle(game_word)
    word_this_round = game_word[0]
    game_word.pop(0)
    masked_word = len(word_this_round) * '\u25A0'
    
    
    word_this_round_in_set = {}
    while health > 0 and masked_word!=word_this_round:

        print(f'{masked_word} |\u2660{health}')
        input_word = str(input('Назовите букву или слово целиком: '))
            
        input_word_in_set = set(input_word)
        input_word_in_list = ' '.join(input_word).split()
        
        marker = 0
        
        word_this_round_in_set = set(word_this_round)
        for i in range(len(input_word_in_list)):
            if input_word_in_list[i] not in word_this_round_in_set:
                marker +=1
                break
            
        masked_word = ' '.join(masked_word).split()
        
        
        for i in range(len(word_this_round)):
            if word_this_round[i] in input_word_in_set:
                masked_word[i] = word_this_round[i]
        for i in range(marker):
            health -=1
        masked_word = ''.join(masked_word)
    if health >0:
        print('Вы выйграли, приз автомобиль')
    else:
        print('Вы проиграли')
        
    print('Не хотите сыграть занаво? д/н')
    choose_game = str(input())
    if choose_game == 'д':
        gameplay()
    else:
        print('До свидания')
gameplay()
# Out:
# Введите сложность игры
# сложный
# ■■■■■ |♠3
# Назовите букву или слово целиком: м
# ■■■■■ |♠2
# Назовите букву или слово целиком: а
# ■■■■а |♠2
# Назовите букву или слово целиком: книга
# Вы выйграли, приз автомобиль
# Не хотите сыграть занаво? д/н
# д
# Введите сложность игры
# средний
# ■■■■■■■ |♠5
# Назовите букву или слово целиком: а
# ■а■а■■■ |♠5
# Назовите букву или слово целиком: сн
# са■а■■н |♠5
# Назовите букву или слово целиком: сахалин
# Вы выйграли, приз автомобиль
# Не хотите сыграть занаво? д/н
# д
# Введите сложность игры
# лёгкий
# ■■■ |♠7
# Назовите букву или слово целиком: зуб
# Вы выйграли, приз автомобиль
# Не хотите сыграть занаво? д/н
# д
# Введите сложность игры
# сложный
# ■■■■■ |♠3
# Назовите букву или слово целиком: книга
# ■■■■■ |♠2
# Назовите букву или слово целиком: а
# ■■■■■ |♠1
# Назовите букву или слово целиком: м
# м■■■■ |♠1
# Назовите букву или слово целиком: месяц
# Вы выйграли, приз автомобиль
# Не хотите сыграть занаво? д/н
# д
# Игра закончена
# ...

# %%
import random as rnd
import sys
game_word = ['книга', 'сахалин','месяц','зуб']
def gameplay():
    if len(game_word) == 0:
        print('Игра закончена')
        sys.exit('Игра закончена')
    health = int
    d = {'лёгкий': 7, 'средний': 5, 'сложный': 3}
    
    print('Введите сложность игры')
    choose = str(input())
    health = d[choose]
    
    
    rnd.shuffle(game_word)
    word_this_round = game_word[0]
    game_word.pop(0)
    masked_word = len(word_this_round) * '\u25A0'
    
    
    word_this_round_in_set = {}
    while health > 0 and masked_word!=word_this_round:

        print(f'{masked_word} |\u2660{health}')
        input_word = str(input('Назовите букву или слово целиком: '))
            
        input_word_in_set = set(input_word)
        input_word_in_list = ' '.join(input_word).split()
        
        marker = 0
        
        word_this_round_in_set = set(word_this_round)
        for i in range(len(input_word_in_list)):
            if input_word_in_list[i] not in word_this_round_in_set:
                marker +=1
                break
            
        masked_word = ' '.join(masked_word).split()
        
        
        for i in range(len(word_this_round)):
            if word_this_round[i] in input_word_in_set:
                masked_word[i] = word_this_round[i]
        for i in range(marker):
            health -=1
        masked_word = ''.join(masked_word)
    if health >0:
        print('Вы выйграли, приз автомобиль')
    else:
        print('Вы проиграли')
        
    print('Не хотите сыграть занаво? д/н')
    choose_game = str(input())
    if choose_game == 'д':
        gameplay()
    else:
        print('До свидания')
gameplay()
# Out:
# Введите сложность игры
# сложный
# ■■■■■ |♠3
# Назовите букву или слово целиком: й
# ■■■■■ |♠2
# Назовите букву или слово целиком: й
# ■■■■■ |♠1
# Назовите букву или слово целиком: й
# Вы проиграли
# Не хотите сыграть занаво? д/н
# н
# До свидания
